# %%
using Polynomials,PyPlot,SeisProcessing,DelimitedFiles
# Out:
# ArgumentError: Package Polynomials not found in current path:
# - Run `import Pkg; Pkg.add("Polynomials")` to install the Polynomials package.
#
#
# Stacktrace:
#  [1] require(::Module, ::Symbol) at ./loading.jl:823
#  [2] top-level scope at In[1]:1

# %%
w=(3,-3,1,3,5,0,1)
P = Polynomial(w)
# Out:
# ImmutablePolynomial(3 - 3*x + x^2 + 3*x^3 + 5*x^4 + x^6)

# %%
R = roots(P)
polar(angle.(R),abs.(R),"*")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fa1c9290b10>
